# %%
#Notebook to load larger database and run analysis

# %%
import pandas as pd

# %%
# Read the CSV file
combined_data = pd.read_csv("Final_Dataset_Project3.csv")

# %%
len(combined_data)
# Out:
# 2366776

# %%
# View the first 5 rows
combined_data.head()
# Out:
#   State_Code  County_Code  Site Num  Parameter Code  POC   Latitude  \
# 0         54         61.0       5.0         42401.0  1.0  39.648414
# 1         54         69.0       7.0         42401.0  1.0  40.120502
# 2         54         69.0       7.0         42401.0  1.0  40.120502
# 3         54         69.0       7.0         42401.0  1.0  40.120502
# 4         54         69.0       7.0         42401.0  1.0  40.120502
#
#    Longitude  Datum  Parameter Name Sample Duration  ... Hazardous Days  \
# 0 -79.957563  WGS84  Sulfur dioxide    3-HR BLK AVG  ...            0.0
# 1 -80.699067  WGS84  Sulfur dioxide          1 HOUR  ...            0.0
# 2 -80.699067  WGS84  Sulfur dioxide          1 HOUR  ...            0.0
# 3 -80.699067  WGS84  Sulfur dioxide   24-HR BLK AVG  ...            0.0
# 4 -80.699067  WGS84  Sulfur dioxide    3-HR BLK AVG  ...            0.0
#
#   Max AQI 90th Percentile AQI  Median AQI Days CO Days NO2  Days Ozone  \
# ...

# %%
combined_data.dtypes
# Out:
# State_Code         object
# County_Code       float64
# Site Num          float64
# Parameter Code    float64
# POC               float64
#                    ...
# Days NO2          float64
# Days Ozone        float64
# Days PM2.5        float64
# Days PM10         float64
# Farm Count         object
# Length: 66, dtype: object

# %%
list(combined_data.columns)
# Out:
# ['State_Code',
#  'County_Code',
#  'Site Num',
#  'Parameter Code',
#  'POC',
#  'Latitude',
#  'Longitude',
#  'Datum',
#  'Parameter Name',
#  'Sample Duration',
#  'Pollutant Standard',
#  'Metric Used',
#  'Method Name',
#  'Year',
#  'Units of Measure',
#  'Event Type',
#  'Observation Count',
#  'Observation Percent',
#  'Completeness Indicator',
#  'Valid Day Count',
#  'Required Day Count',
#  'Exceptional Data Count',
#  'Null Data Count',
#  'Primary Exceedance Count',
#  'Secondary Exceedance Count',
#  'Certification Indicator',
#  'Num Obs Below MDL',
#  'Arithmetic Mean',
#  'Arithmetic Standard Dev',
#  '1st Max Value',
#  '1st Max DateTime',
#  '2nd Max Value',
#  '2nd Max DateTime',
#  '3rd Max Value',
#  '3rd Max DateTime',
#  '4th Max Value',
#  '4th Max DateTime',
#  '99th Percentile',
#  '98th Percentile',
#  '95th Percentile',
#  '90th Percentile',
#  '75th Percentile',
#  '50th Percentile',
#  '10th Percentile',
#  'Local Site Name',
#  'Address',
# ...
