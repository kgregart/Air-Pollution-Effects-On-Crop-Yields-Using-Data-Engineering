# %%
#https://saturncloud.io/blog/how-to-import-multiple-csv-files-into-pandas-and-concatenate-into-one-dataframe/

# %%
import pandas as pd

# %%
import os
path = '../CONC_BY_MONITOR/'
extension = '.csv'

# %%
files = [file for file in os.listdir(path) if file.endswith(extension)]

# %%
dfs = []
for file in files:
    df = pd.read_csv(os.path.join(path, file))
    dfs.append(df)
# Out:
# /var/folders/dp/4nbvldw1517_wcddmk64ktnm0000gn/T/ipykernel_23538/3796317544.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, file))
# /var/folders/dp/4nbvldw1517_wcddmk64ktnm0000gn/T/ipykernel_23538/3796317544.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, file))
# /var/folders/dp/4nbvldw1517_wcddmk64ktnm0000gn/T/ipykernel_23538/3796317544.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, file))
# /var/folders/dp/4nbvldw1517_wcddmk64ktnm0000gn/T/ipykernel_23538/3796317544.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, file))
# /var/folders/dp/4nbvldw1517_wcddmk64ktnm0000gn/T/ipykernel_23538/3796317544.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, file))
# /var/folders/dp/4nbvldw1517_wcddmk64ktnm0000gn/T/ipykernel_23538/3796317544.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, file))
# /var/folders/dp/4nbvldw1517_wcddmk64ktnm0000gn/T/ipykernel_23538/3796317544.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, file))
# /var/folders/dp/4nbvldw1517_wcddmk64ktnm0000gn/T/ipykernel_23538/3796317544.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, file))
# /var/folders/dp/4nbvldw1517_wcddmk64ktnm0000gn/T/ipykernel_23538/3796317544.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, file))
# /var/folders/dp/4nbvldw1517_wcddmk64ktnm0000gn/T/ipykernel_23538/3796317544.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, file))
# /var/folders/dp/4nbvldw1517_wcddmk64ktnm0000gn/T/ipykernel_23538/3796317544.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, file))
# /var/folders/dp/4nbvldw1517_wcddmk64ktnm0000gn/T/ipykernel_23538/3796317544.py:3: DtypeWarning: Columns (0,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, file))

# %%
df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#         State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0                1            3        10           44201    1  30.497478
# 1                1            3        10           44201    1  30.497478
# 2                1            3        10           44201    1  30.497478
# 3                1            3        10           44201    1  30.497478
# 4                1            3        10           88101    1  30.497478
# ...            ...          ...       ...             ...  ...        ...
# 2224003         CC           11         2           88101    1  49.135138
# 2224004         CC           11         2           88101    1  49.135138
# 2224005         CC           11         2           88101    1  49.135138
# 2224006         CC           11         2           88101    1  49.135138
# 2224007         CC           11         2           88101    1  49.135138
#
#           Longitude  Datum            Parameter Name          Sample Duration  \
# 0        -87.880258  NAD83                     Ozone                   1 HOUR
# 1        -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR
# 2        -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR
# 3        -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR
# 4        -87.880258  NAD83  PM2.5 - Local Conditions                  24 HOUR
# ...             ...    ...                       ...                      ...
# 2224003 -102.984855  WGS84  PM2.5 - Local Conditions                  24 HOUR
# 2224004 -102.984855  WGS84  PM2.5 - Local Conditions                  24 HOUR
# 2224005 -102.984855  WGS84  PM2.5 - Local Conditions                  24 HOUR
# 2224006 -102.984855  WGS84  PM2.5 - Local Conditions                  24 HOUR
# 2224007 -102.984855  WGS84  PM2.5 - Local Conditions                  24 HOUR
#
#          ... 75th Percentile 50th Percentile 10th Percentile  \
# 0        ...           0.054           0.044           0.030
# 1        ...           0.049           0.039           0.026
# 2        ...           0.049           0.039           0.026
# 3        ...           0.048           0.039           0.026
# 4        ...           8.600           6.600           4.000
# ...      ...             ...             ...             ...
# 2224003  ...           7.900           5.800           4.200
# 2224004  ...           7.900           5.800           4.200
# 2224005  ...           7.900           5.800           4.200
# 2224006  ...           7.900           5.800           4.200
# 2224007  ...           7.900           5.800           4.200
#
#            Local Site Name                                            Address  \
# 0        FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 1        FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 2        FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 3        FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 4        FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# ...                    ...                                                ...
# 2224003                NaN                                        ESTEVAN, SK
# 2224004                NaN                                        ESTEVAN, SK
# 2224005                NaN                                        ESTEVAN, SK
# 2224006                NaN                                        ESTEVAN, SK
# 2224007                NaN                                        ESTEVAN, SK
#
#         State Name   County Name      City Name                  CBSA Name  \
# 0          Alabama       Baldwin       Fairhope  Daphne-Fairhope-Foley, AL
# 1          Alabama       Baldwin       Fairhope  Daphne-Fairhope-Foley, AL
# 2          Alabama       Baldwin       Fairhope  Daphne-Fairhope-Foley, AL
# 3          Alabama       Baldwin       Fairhope  Daphne-Fairhope-Foley, AL
# 4          Alabama       Baldwin       Fairhope  Daphne-Fairhope-Foley, AL
# ...            ...           ...            ...                        ...
# 2224003     Canada  Saskatchewan  Not in a city                        NaN
# 2224004     Canada  Saskatchewan  Not in a city                        NaN
# 2224005     Canada  Saskatchewan  Not in a city                        NaN
# 2224006     Canada  Saskatchewan  Not in a city                        NaN
# 2224007     Canada  Saskatchewan  Not in a city                        NaN
#
#          Date of Last Change
# 0                 2021-11-03
# 1                 2021-11-03
# 2                 2021-11-03
# 3                 2021-11-03
# 4                 2023-05-16
# ...                      ...
# 2224003           2021-11-09
# 2224004           2021-11-09
# 2224005           2021-11-09
# 2224006           2021-11-09
# 2224007           2021-11-09
#
# [2224008 rows x 55 columns]

# %%
df.dtypes
# Out:
# State Code                        object
# County Code                        int64
# Site Num                           int64
# Parameter Code                     int64
# POC                                int64
# Latitude                         float64
# Longitude                        float64
# Datum                             object
# Parameter Name                    object
# Sample Duration                   object
# Pollutant Standard                object
# Metric Used                       object
# Method Name                       object
# Year                               int64
# Units of Measure                  object
# Event Type                        object
# Observation Count                  int64
# Observation Percent                int64
# Completeness Indicator            object
# Valid Day Count                    int64
# Required Day Count                 int64
# Exceptional Data Count             int64
# Null Data Count                    int64
# Primary Exceedance Count         float64
# Secondary Exceedance Count       float64
# Certification Indicator           object
# Num Obs Below MDL                  int64
# Arithmetic Mean                  float64
# Arithmetic Standard Dev          float64
# 1st Max Value                    float64
# 1st Max DateTime                  object
# 2nd Max Value                    float64
# 2nd Max DateTime                  object
# 3rd Max Value                    float64
# 3rd Max DateTime                  object
# 4th Max Value                    float64
# 4th Max DateTime                  object
# 1st Max Non Overlapping Value    float64
# 1st NO Max DateTime               object
# 2nd Max Non Overlapping Value    float64
# 2nd NO Max DateTime               object
# 99th Percentile                  float64
# 98th Percentile                  float64
# 95th Percentile                  float64
# 90th Percentile                  float64
# 75th Percentile                  float64
# 50th Percentile                  float64
# 10th Percentile                  float64
# Local Site Name                   object
# Address                           object
# State Name                        object
# County Name                       object
# City Name                         object
# CBSA Name                         object
# Date of Last Change               object
# dtype: object

# %%
list(df.columns)
# Out:
# ['State Code',
#  'County Code',
#  'Site Num',
#  'Parameter Code',
#  'POC',
#  'Latitude',
#  'Longitude',
#  'Datum',
#  'Parameter Name',
#  'Sample Duration',
#  'Pollutant Standard',
#  'Metric Used',
#  'Method Name',
#  'Year',
#  'Units of Measure',
#  'Event Type',
#  'Observation Count',
#  'Observation Percent',
#  'Completeness Indicator',
#  'Valid Day Count',
#  'Required Day Count',
#  'Exceptional Data Count',
#  'Null Data Count',
#  'Primary Exceedance Count',
#  'Secondary Exceedance Count',
#  'Certification Indicator',
#  'Num Obs Below MDL',
#  'Arithmetic Mean',
#  'Arithmetic Standard Dev',
#  '1st Max Value',
#  '1st Max DateTime',
#  '2nd Max Value',
#  '2nd Max DateTime',
#  '3rd Max Value',
#  '3rd Max DateTime',
#  '4th Max Value',
#  '4th Max DateTime',
#  '1st Max Non Overlapping Value',
#  '1st NO Max DateTime',
#  '2nd Max Non Overlapping Value',
#  '2nd NO Max DateTime',
#  '99th Percentile',
#  '98th Percentile',
#  '95th Percentile',
#  '90th Percentile',
#  '75th Percentile',
#  '50th Percentile',
#  '10th Percentile',
#  'Local Site Name',
#  'Address',
#  'State Name',
#  'County Name',
#  'City Name',
#  'CBSA Name',
#  'Date of Last Change']

# %%
clean_df = df.drop(columns=['1st Max Non Overlapping Value',
 '1st NO Max DateTime',
 '2nd Max Non Overlapping Value',
 '2nd NO Max DateTime','Date of Last Change'])

# %%
clean_df.head()
# Out:
#   State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0          1            3        10           44201    1  30.497478
# 1          1            3        10           44201    1  30.497478
# 2          1            3        10           44201    1  30.497478
# 3          1            3        10           44201    1  30.497478
# 4          1            3        10           88101    1  30.497478
#
#    Longitude  Datum            Parameter Name          Sample Duration  ...  \
# 0 -87.880258  NAD83                     Ozone                   1 HOUR  ...
# 1 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 2 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 3 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 4 -87.880258  NAD83  PM2.5 - Local Conditions                  24 HOUR  ...
#
#   90th Percentile 75th Percentile 50th Percentile  10th Percentile  \
# 0           0.061           0.054           0.044            0.030
# 1           0.054           0.049           0.039            0.026
# 2           0.054           0.049           0.039            0.026
# 3           0.054           0.048           0.039            0.026
# 4          10.900           8.600           6.600            4.000
#
#      Local Site Name                                            Address  \
# 0  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 1  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 2  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 3  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 4  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
#
#    State Name  County Name City Name                  CBSA Name
# 0     Alabama      Baldwin  Fairhope  Daphne-Fairhope-Foley, AL
# 1     Alabama      Baldwin  Fairhope  Daphne-Fairhope-Foley, AL
# 2     Alabama      Baldwin  Fairhope  Daphne-Fairhope-Foley, AL
# 3     Alabama      Baldwin  Fairhope  Daphne-Fairhope-Foley, AL
# 4     Alabama      Baldwin  Fairhope  Daphne-Fairhope-Foley, AL
#
# [5 rows x 50 columns]

# %%
list(clean_df.columns)
# Out:
# ['State Code',
#  'County Code',
#  'Site Num',
#  'Parameter Code',
#  'POC',
#  'Latitude',
#  'Longitude',
#  'Datum',
#  'Parameter Name',
#  'Sample Duration',
#  'Pollutant Standard',
#  'Metric Used',
#  'Method Name',
#  'Year',
#  'Units of Measure',
#  'Event Type',
#  'Observation Count',
#  'Observation Percent',
#  'Completeness Indicator',
#  'Valid Day Count',
#  'Required Day Count',
#  'Exceptional Data Count',
#  'Null Data Count',
#  'Primary Exceedance Count',
#  'Secondary Exceedance Count',
#  'Certification Indicator',
#  'Num Obs Below MDL',
#  'Arithmetic Mean',
#  'Arithmetic Standard Dev',
#  '1st Max Value',
#  '1st Max DateTime',
#  '2nd Max Value',
#  '2nd Max DateTime',
#  '3rd Max Value',
#  '3rd Max DateTime',
#  '4th Max Value',
#  '4th Max DateTime',
#  '99th Percentile',
#  '98th Percentile',
#  '95th Percentile',
#  '90th Percentile',
#  '75th Percentile',
#  '50th Percentile',
#  '10th Percentile',
#  'Local Site Name',
#  'Address',
#  'State Name',
#  'County Name',
#  'City Name',
#  'CBSA Name']

# %%
list(clean_df.Year.unique())
# Out:
# [2018,
#  2019,
#  2022,
#  2023,
#  2009,
#  2021,
#  2020,
#  2008,
#  1994,
#  1995,
#  1997,
#  1996,
#  1993,
#  1998,
#  1999,
#  2005,
#  2011,
#  2004,
#  2012,
#  2006,
#  2007,
#  2013,
#  2017,
#  2003,
#  2002,
#  2016,
#  2000,
#  2014,
#  2015,
#  2001]

# %%
clean_df.to_csv('combined_annual_conc_by_monitor.csv')
